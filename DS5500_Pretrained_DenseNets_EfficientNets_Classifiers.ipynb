# %%
# Import Neccessary Libraries:

import numpy as np
import pandas as pd
import torch
from torchvision import datasets, transforms, models
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, Dataset
from torch import nn
import torch.nn.functional as F
from torch import optim
from torch.optim.lr_scheduler import ReduceLROnPlateau
from tqdm import tqdm
import pickle
from torch.optim.lr_scheduler import StepLR
import time
from PIL import Image
from torchsummary import summary
import time
import cv2

import seaborn as sns

pd.set_option('display.max_colwidth', -1)
pd.set_option("display.max_rows", 100000)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:24: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
# To mount drive:
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Checking GPU:
print(torch.cuda.get_device_name(0))
# Out:
# Tesla P100-PCIE-16GB

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
def get_data_from_drive(copy = True, extract = True):
  start = time.time()
  if copy:
    print("Copying Train Source from Drive.")
    # !cp "/content/drive/MyDrive/DS5500 Data/nasa_tropical_storm_competition_train_source.tar" -r "/content/nasa_tropical_storm_competition_train_source.tar"
    print("Copying Test Source from Drive.")
    # !cp "/content/drive/MyDrive/DS5500 Data/nasa_tropical_storm_competition_test_source.tar" -r "/content/nasa_tropical_storm_competition_test_source.tar"
    print("Copying Train Metadata from Drive.")
    # !cp "/content/drive/MyDrive/DS5500 Data/train.csv" -r "/content/train.csv"
    print("Copying Test Metadata from Drive.")
    # !cp "/content/drive/MyDrive/DS5500 Data/test.csv" -r "/content/test.csv"

  if extract:
    print("Extracting Training Images")
    # !tar -xvf "/content/nasa_tropical_storm_competition_train_source.tar" -C "/content/"
    print("Extracting Test Images")
    # !tar -xvf "/content/nasa_tropical_storm_competition_test_source.tar" -C "/content/"
  
  print("Data Ready! Time Taken: {:.4f}s".format(time.time() - start))

  
def get_image_paths(data, image_dir, folder_name):
    data["image_path"] = image_dir + "/" + folder_name + "_" + data["image_id"] + "/" + "image.jpg"
    data = data[data.columns[[0, 2, 5, 1, 3, 4]]]
    return data

# %%
def write_model_losses(filename, losses):
  print("Saving model losses to drive.")
  with open("/content/drive/MyDrive/DS5500 Data/{}.pkl".format(filename), "wb") as f:
    pickle.dump(losses, f)
    

def plot_predictions(wind_speed, metadata):
    sample_img = metadata[metadata.wind_speed == wind_speed][["image_path","predictions"]].iloc[:5]
    for i,img in enumerate(sample_img.image_path):
        # im = Image.open(img) 
        # im.show(title = sample_img["predictions"].iloc[i])
        image = mpimg.imread(img)
        plt.title("Actual: "+ str(wind_speed) +"   Predicted: " + str(round(sample_img["predictions"].iloc[i],2)))
        plt.imshow(image, cmap = "gray")
        plt.show()
    return 

def loadModel(model_path, model = None):
  state_dict = torch.load(model_path)
  model.load_state_dict(state_dict)
  return model

# %%
# extract and save losses from model training print statements

def extract_and_save_losses_from_print_statements(loss_text, model_name, save=False):
  loss_text_list = loss_text.split("\n")
  loss_text_list = [text for text in loss_text_list if text.startswith("Epoch:")]
  loss_text_list = [text.split(",") for text in loss_text_list]
  # loss_text_list
  losses = {"train_loss": [], "valid_loss": []}
  for i in loss_text_list:
    losses["train_loss"].append(float(i[1].split(":")[1].strip()))
    losses["valid_loss"].append(float(i[2].split(":")[1].strip()))

  # model_name = "baseline_CNN_ADAM_0.0001"
  losses_filename = "{}_losses".format(model_name)
  if save:
    write_model_losses(losses_filename, losses)
  
  return losses

# %%
def get_data_in_intervals(metadata, interval):
  
  data_dict = dict()
  counter = 0
  for name, group in metadata.groupby(by="storm_id"):
    group = group.sort_values(by="relative_time").reset_index()
    # print(name, group.index)
    # removing storms with just one rgb image
    if group.shape[0] > 2*interval+1:
      for i in range(0, group.shape[0]):
        i2 = i-interval
        i3 = i2-interval
        if i3 >= 0 and i2 > 0:
          # print(i, i2, i3)
          lis = [group.image_path[i3], group.image_path[i2], group.image_path[i]]
          # storm_id = metadata.storm_id[i3]
          wind_speed = group.wind_speed[i]

          if counter not in data_dict.keys():
            data_dict[counter] = {"storm_id": name, "image_list": lis, "wind_speed": wind_speed, "ocean":  group.ocean[i]}
          counter += 1

  df = pd.DataFrame.from_dict(data_dict, orient="index").reset_index().drop(columns="index")

  return df

# %%
def create_bins(df):
  # specify condition
  conditions = [(df["wind_speed"] >= 15) & (df["wind_speed"] <= 25),
                (df["wind_speed"] >= 26) & (df["wind_speed"] <= 35),
                (df["wind_speed"] >= 36) & (df["wind_speed"] <= 45),
                (df["wind_speed"] >= 45) & (df["wind_speed"] <= 75),
                # (df["wind_speed"] >= 76) & (df["wind_speed"] <= 90),
                (df["wind_speed"] > 75)]

  values = ["15 to 25", "26 to 35", "36 to 45", "46 to 75", ">=76"]


  df["Wind Labels"] = np.select(conditions, values)
  print("Bins created!")

  return df

# %%
def display_sample_images(dataloader, batch_size, sample_size, num_rows, class_dict):

  sample_size = min(sample_size, batch_size)
  images, labels = next(iter(dataloader))
  images = images.numpy()

  fig = plt.figure(figsize = (30, 10))
  for i in np.arange(sample_size):
      ax = fig.add_subplot(num_rows, sample_size/num_rows, i+1, xticks = [], yticks = [])
      ax.imshow(np.squeeze(np.transpose(images[i], (1, 2 ,0))))
      ax.set_title("Wind Label: {}".format(str(class_dict[labels[i].item()])))
      # ax.set_title(str(get_labels_for_one_hot(labels[i], class_dict)))
  
  return

# %%
class HurricaneImageDataset(Dataset):

    def __init__(self, metadata, transforms, add_color=False):
        self.metadata = metadata # new: with list of image paths, wind speed
        self.transforms = transforms
        self.add_color = add_color

    def __len__(self):
        return len(self.metadata)

    def convert_to_threeband(self, img_list):
      def add_rgb_to_images(img):
        # create 1 pixel red image
        red = np.zeros((1, 1, 3), np.uint8)
        red[:] = (0,0,255)
        # resize lut to 256 values
        # # create 1 pixel blue image
        blue = np.zeros((1, 1, 3), np.uint8)
        blue[:] = (255,0,0)
        # resize lut to 256 values
        # # create 1 pixel green image
        green = np.zeros((1, 1, 3), np.uint8)
        green[:] = (0,255,0)
        # append the three images
        lut = np.concatenate((red, green, blue), axis=0)
        lut = cv2.resize(lut, (1,256), interpolation=cv2.INTER_CUBIC)
        # apply lut
        result = cv2.LUT(img, lut)
        return result
      
      # Reading the three images
      img1 = cv2.imread(img_list[0], cv2.IMREAD_GRAYSCALE) # t - 2*interval
      img2 = cv2.imread(img_list[1], cv2.IMREAD_GRAYSCALE) # t - interval
      img3 = cv2.imread(img_list[2], cv2.IMREAD_GRAYSCALE) # t

      # Merge the three images to convert to three equal channels
      img = cv2.merge((img3, img2, img1))
      # img = img/255
      # print(img)

      # Add color if True
      if self.add_color:
        img = add_rgb_to_images(img)
        
      # return np.asarray(img)
      # return img
      return Image.fromarray(img)

    def __getitem__(self, index):
      if torch.is_tensor(index):
          index = index.tolist()

      # rgb_image = []
      image_paths = self.metadata["image_list"][index]
      hurricane_image = self.convert_to_threeband(image_paths)
      # for ip in image_paths:
      #   img = Image.open(image_path)
      #   rgb_image.append(img)
      # hurricane_image = io.imread(image_path)
      
      label = self.metadata["wind_label_encoded"][index]

      if self.transforms:
          hurricane_image = self.transforms(hurricane_image)

      return hurricane_image, label

# %%
from sklearn.preprocessing import LabelEncoder
def label_encode(df, col_name):
  le = LabelEncoder()
  le.fit(df[col_name])
  df['wind_label_encoded'] = le.transform(df[col_name])
  classes = {i:cls for i,cls in enumerate(le.classes_)}
  return df, classes

# %%
def train(model, trainloader, validloader, epochs, criterion, optimizer, scheduler, device, model_name, losses_filename):

  valid_loss_min = np.Inf
  losses = {"train_loss": [], "valid_loss": []}
  start = time.time()

  for e in range(1, epochs + 1):
    train_loss, valid_loss = 0.0, 0.0

    # Training the model:
    model.train()
    for data, target in trainloader:
        data, target = data.to(device), target.to(device)
        # target = target.float().unsqueeze(1)
        optimizer.zero_grad()
        output = model(data)
        # print("Size: {}".format(output.size()))
        loss = criterion(output, target)
        loss.backward()
        # print(loss)
        optimizer.step()
        train_loss += loss.item() * data.size(0)

    # Validating the model:
    model.eval()
    for data, target in validloader:
        data, target = data.to(device), target.to(device)
        # target = target.float().unsqueeze(1)
        output = model(data)
        loss = criterion(output, target)
        valid_loss += loss.item() * data.size(0)
    
    if scheduler is not None:
        scheduler.step(valid_loss)

    train_loss = train_loss / len(trainloader.dataset)
    losses["train_loss"].append(train_loss)
    valid_loss = valid_loss / len(validloader.dataset)
    losses["valid_loss"].append(valid_loss)
    write_model_losses(losses_filename, losses)

    print("Epoch: {}/{}, Train Loss: {:.5f}, Validation Loss: {:.5f}".format(e, epochs, train_loss, valid_loss))


    if valid_loss <= valid_loss_min:
        print('Decrease in Validation Loss: ({:.6f} to {:.6f}). Saving Model...'.format(
            valid_loss_min,
            valid_loss))
        torch.save(model.state_dict(), "/content/drive/MyDrive/DS5500 Data/{}.pt".format(model_name))
        valid_loss_min = valid_loss
    
  end = time.time()
  hours, rem = divmod(end-start, 3600)
  minutes, seconds = divmod(rem, 60)
  print("\nTime Taken for Training: {:0>2}:{:0>2}:{:05.2f}\n".format(int(hours),int(minutes),seconds))
  write_model_losses(losses_filename, losses)
    
  return losses

# %%
def model_evaluation(dataloader, model, criterion, device):
    # specify loss function
  predictions = torch.FloatTensor().cpu()
    # criterion = nn.MSELoss()
  total_MSE_loss, total_RMSE_loss = 0.0, 0.0
    # specify optimizer
    # optimizer = optim.Adam(model.parameters(), lr = 0.015)
  model.eval()
    # for data, target in validloader:
    #     data, target = data.to(device), target.to(device)
    #     target = target.float().unsqueeze(1)
    #     output = model(data)
    #     loss = criterion(output, target)
    #     valid_loss += loss.item() * data.size(0)
  with torch.no_grad():
    for data, target in dataloader:
        data, target = data.to(device), target.to(device)
        target = target.float().unsqueeze(1)
        output = model(data)
        predictions = torch.cat((predictions, output.cpu()), 0)
        # print(predictions)
        #RMSE
        MSE_loss = criterion(output, target)
        RMSE_loss = torch.sqrt(MSE_loss)
        total_MSE_loss += MSE_loss.item()*data.size(0)
        total_RMSE_loss += RMSE_loss.item()*data.size(0)
    total_MSE_loss = total_MSE_loss / len(dataloader.dataset)
    total_RMSE_loss = total_RMSE_loss / len(dataloader.dataset)

  # pass entire testloader, get outputs and append to test_metadata
  preds_df = pd.DataFrame(predictions, columns = ['predictions']).astype("float")
  return preds_df, total_MSE_loss, total_RMSE_loss

# %%
# Testing Model on Data:

def test(model, testloader, criterion, num_classes, class_dict):

  test_loss, accuracy = 0.0, 0.0
  class_correct = list(0. for i in range(num_classes))
  class_total = list(0. for i in range(num_classes))
  model.eval()

  for images, labels in testloader:
      images, labels = images.to(device), labels.to(device)
      output = model(images)
      loss = criterion(output, labels)
      test_loss += loss.item()*images.size(0)
      _, pred = torch.max(output, 1)
      correct = np.squeeze(pred.eq(labels.data.view_as(pred)))

      for i in range(len(labels)):
          label = labels.data[i]
          class_correct[label] += correct[i].item()
          class_total[label] += 1

  test_loss = test_loss/len(testloader.sampler)
  print("Test Loss: {}".format(test_loss))

  for i in range(num_classes):
      if class_total[i] > 0:
          print("Test Accuracy of {}: {:.3f}%. Frac: {}/{}".format(str(class_dict[i]), 100*(class_correct[i]/class_total[i]), 
                                                        np.sum(class_correct[i]), np.sum(class_total[i])))
      else:
          print("Test Accuracy of {}: N/A (no training examples)".format(classes[i]))
  print("\n Test Accuracy (Overall): {:.3f}. Frac {}/{}".format((100 * np.sum(class_correct)/np.sum(class_total)), 
                                                            np.sum(class_correct), np.sum(class_total)))
  
  return

# %%
get_data_from_drive(copy=True, extract=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kzg_017/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kzg_017/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kzg_017/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_num_004/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_num_004/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_num_004/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_num_004/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hld_147/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hld_147/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hld_147/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hld_147/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tkl_108/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tkl_108/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tkl_108/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tkl_108/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oxm_187/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oxm_187/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oxm_187/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oxm_187/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_sqt_093/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_sqt_093/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_sqt_093/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_sqt_093/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_vlz_080/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_vlz_080/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_vlz_080/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_vlz_080/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_frh_121/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_frh_121/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_frh_121/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_frh_121/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dpf_109/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dpf_109/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dpf_109/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dpf_109/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_433/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_433/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_433/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_433/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kop_127/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kop_127/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kop_127/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kop_127/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hze_274/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hze_274/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hze_274/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hze_274/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_azb_106/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_azb_106/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_azb_106/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_azb_106/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bib_106/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bib_106/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bib_106/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bib_106/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tzf_385/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tzf_385/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tzf_385/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tzf_385/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xsc_141/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xsc_141/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xsc_141/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xsc_141/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_crw_170/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_crw_170/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_crw_170/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_crw_170/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jql_481/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jql_481/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jql_481/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jql_481/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_agb_109/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_agb_109/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_agb_109/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_agb_109/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_yzi_044/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_yzi_044/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_yzi_044/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_yzi_044/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_agl_259/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_agl_259/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_agl_259/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_agl_259/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_nma_170/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_nma_170/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_nma_170/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_nma_170/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hzo_030/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hzo_030/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hzo_030/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hzo_030/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mtj_072/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mtj_072/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mtj_072/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mtj_072/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qlc_121/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qlc_121/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qlc_121/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qlc_121/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jhp_459/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jhp_459/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jhp_459/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jhp_459/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_khd_085/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_khd_085/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_khd_085/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_khd_085/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jlj_103/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jlj_103/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jlj_103/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jlj_103/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fmv_128/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fmv_128/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fmv_128/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fmv_128/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_iiz_305/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_iiz_305/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_iiz_305/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_iiz_305/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kmb_154/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kmb_154/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kmb_154/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kmb_154/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zbn_118/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zbn_118/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zbn_118/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zbn_118/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_stv_106/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_stv_106/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_stv_106/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_stv_106/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fhl_307/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fhl_307/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fhl_307/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fhl_307/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_txn_082/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_txn_082/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_txn_082/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_txn_082/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oar_189/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oar_189/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oar_189/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oar_189/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rxs_007/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rxs_007/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rxs_007/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rxs_007/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tja_203/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tja_203/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tja_203/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tja_203/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hgj_155/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hgj_155/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hgj_155/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hgj_155/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_frt_035/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_frt_035/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_frt_035/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_frt_035/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jhp_297/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jhp_297/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jhp_297/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jhp_297/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fpr_138/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fpr_138/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fpr_138/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fpr_138/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qsv_037/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qsv_037/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qsv_037/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qsv_037/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kxm_112/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kxm_112/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kxm_112/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kxm_112/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qfa_183/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qfa_183/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qfa_183/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qfa_183/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ozs_161/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ozs_161/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ozs_161/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ozs_161/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oyz_011/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oyz_011/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oyz_011/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oyz_011/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_erp_094/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_erp_094/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_erp_094/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_erp_094/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_imi_230/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_imi_230/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_imi_230/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_imi_230/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_awy_201/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_awy_201/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_awy_201/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_awy_201/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fhl_145/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fhl_145/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fhl_145/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fhl_145/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xum_037/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xum_037/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xum_037/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xum_037/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_orp_289/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_orp_289/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_orp_289/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_orp_289/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zez_119/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zez_119/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zez_119/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zez_119/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_271/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_271/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_271/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_271/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fkd_078/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fkd_078/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fkd_078/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fkd_078/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hhi_146/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hhi_146/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hhi_146/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hhi_146/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xnp_185/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xnp_185/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xnp_185/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xnp_185/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dva_081/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dva_081/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dva_081/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dva_081/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_pui_042/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_pui_042/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_pui_042/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_pui_042/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rzk_148/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rzk_148/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rzk_148/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rzk_148/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_isi_087/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_isi_087/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_isi_087/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_isi_087/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mtj_234/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mtj_234/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mtj_234/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mtj_234/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ati_123/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ati_123/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ati_123/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ati_123/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rye_121/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rye_121/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rye_121/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rye_121/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_yuo_052/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_yuo_052/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_yuo_052/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_yuo_052/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xzi_180/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xzi_180/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xzi_180/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xzi_180/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_vzn_105/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_vzn_105/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_vzn_105/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_vzn_105/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_eve_022/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_eve_022/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_eve_022/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_eve_022/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ftp_091/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ftp_091/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ftp_091/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ftp_091/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_roe_068/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_roe_068/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_roe_068/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_roe_068/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xze_265/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xze_265/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xze_265/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xze_265/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kqf_110/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kqf_110/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kqf_110/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_kqf_110/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_orj_054/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_orj_054/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_orj_054/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_orj_054/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_lhc_148/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_lhc_148/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_lhc_148/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_lhc_148/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hpo_139/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hpo_139/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hpo_139/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hpo_139/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tbs_038/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tbs_038/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tbs_038/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tbs_038/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fwn_108/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fwn_108/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fwn_108/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fwn_108/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hvz_183/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hvz_183/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hvz_183/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hvz_183/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_uua_063/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_uua_063/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_uua_063/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_uua_063/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tja_122/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tja_122/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tja_122/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tja_122/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qdh_160/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qdh_160/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qdh_160/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qdh_160/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_erd_261/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_erd_261/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_erd_261/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_erd_261/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_cwf_130/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_cwf_130/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_cwf_130/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_cwf_130/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hgj_074/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hgj_074/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hgj_074/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hgj_074/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hld_228/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hld_228/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hld_228/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hld_228/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zcu_020/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zcu_020/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zcu_020/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zcu_020/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oxm_268/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oxm_268/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oxm_268/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oxm_268/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_sqt_174/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_sqt_174/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_sqt_174/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_sqt_174/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fpr_057/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fpr_057/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fpr_057/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fpr_057/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_frh_202/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_frh_202/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_frh_202/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_frh_202/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_514/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_514/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_514/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_514/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hze_355/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hze_355/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hze_355/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hze_355/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tzf_466/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tzf_466/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tzf_466/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tzf_466/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_buc_019/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_buc_019/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_buc_019/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_buc_019/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dhv_099/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dhv_099/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dhv_099/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dhv_099/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_yry_358/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_yry_358/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_yry_358/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_yry_358/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_crw_251/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_crw_251/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_crw_251/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_crw_251/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bdr_183/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bdr_183/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bdr_183/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bdr_183/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jql_562/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jql_562/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jql_562/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_jql_562/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qgb_019/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qgb_019/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qgb_019/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qgb_019/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zez_038/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zez_038/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zez_038/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zez_038/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_eef_040/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_eef_040/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_eef_040/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_eef_040/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_190/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_190/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_190/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dvp_190/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hhi_065/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hhi_065/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hhi_065/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hhi_065/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_nma_251/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_nma_251/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_nma_251/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_nma_251/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tmb_010/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tmb_010/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tmb_010/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tmb_010/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hzo_111/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hzo_111/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hzo_111/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hzo_111/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rzk_067/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rzk_067/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rzk_067/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rzk_067/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mtj_153/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mtj_153/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mtj_153/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mtj_153/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mqj_066/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mqj_066/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mqj_066/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mqj_066/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ati_042/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ati_042/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ati_042/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ati_042/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rye_040/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rye_040/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rye_040/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rye_040/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fit_010/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fit_010/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fit_010/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fit_010/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bmm_017/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bmm_017/image.jpg
# ...
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hzg_173/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hzg_173/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hzg_173/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hzg_173/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qsv_172/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qsv_172/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qsv_172/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_qsv_172/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_etd_061/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_etd_061/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_etd_061/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_etd_061/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tcn_249/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tcn_249/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tcn_249/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tcn_249/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_wpf_052/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_wpf_052/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_wpf_052/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_wpf_052/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_buc_235/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_buc_235/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_buc_235/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_buc_235/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ist_103/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ist_103/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ist_103/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ist_103/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oyc_126/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oyc_126/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oyc_126/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_oyc_126/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_wyn_150/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_wyn_150/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_wyn_150/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_wyn_150/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xtt_022/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xtt_022/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xtt_022/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xtt_022/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zbn_091/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zbn_091/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zbn_091/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zbn_091/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fhl_280/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fhl_280/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fhl_280/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_fhl_280/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xum_172/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xum_172/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xum_172/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_xum_172/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bpu_157/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bpu_157/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bpu_157/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_bpu_157/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dpf_082/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dpf_082/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dpf_082/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dpf_082/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_gio_212/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_gio_212/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_gio_212/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_gio_212/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_cqv_163/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_cqv_163/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_cqv_163/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_cqv_163/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hhi_281/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hhi_281/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hhi_281/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hhi_281/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tpw_027/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tpw_027/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tpw_027/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tpw_027/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_acd_129/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_acd_129/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_acd_129/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_acd_129/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zsh_276/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zsh_276/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zsh_276/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_zsh_276/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_srv_108/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_srv_108/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_srv_108/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_srv_108/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_npg_078/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_npg_078/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_npg_078/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_npg_078/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mpq_132/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mpq_132/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mpq_132/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_mpq_132/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_vwd_003/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_vwd_003/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_vwd_003/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_vwd_003/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dgc_024/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dgc_024/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dgc_024/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_dgc_024/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_igk_117/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_igk_117/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_igk_117/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_igk_117/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_djm_261/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_djm_261/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_djm_261/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_djm_261/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ity_329/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ity_329/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ity_329/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_ity_329/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_uuc_205/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_uuc_205/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_uuc_205/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_uuc_205/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tkl_081/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tkl_081/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tkl_081/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tkl_081/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rib_232/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rib_232/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rib_232/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_rib_232/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hpo_274/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hpo_274/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hpo_274/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hpo_274/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tbs_173/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tbs_173/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tbs_173/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_tbs_173/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_sha_341/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_sha_341/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_sha_341/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_sha_341/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hlv_037/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hlv_037/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hlv_037/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_hlv_037/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_cmg_094/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_cmg_094/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_cmg_094/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_cmg_094/features.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_uac_092/
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_uac_092/image.jpg
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_uac_092/stac.json
# nasa_tropical_storm_competition_test_source/nasa_tropical_storm_competition_test_source_uac_092/features.json
# Data Ready! Time Taken: 162.6389s

# %%
rs = np.random.RandomState(111) # creating a random state for reproducibility of random generators
data_dir = "/content/"
train_metadata_og = pd.read_csv("{}/train.csv".format(data_dir))
test_metadata_og = pd.read_csv("{}/test.csv".format(data_dir))

train_folder_name = "nasa_tropical_storm_competition_train_source"
test_folder_name = "nasa_tropical_storm_competition_test_source"
train_image_dir = "{}/{}".format(data_dir, train_folder_name)
test_image_dir = "{}/{}".format(data_dir, test_folder_name)

# msk = rs.rand(len(train_metadata)) < 0.8
# train_metadata2 = train_metadata[msk].reset_index().drop("index", axis=1)
# valid_metadata = train_metadata[~msk].reset_index().drop("index", axis=1)


train_metadata = get_image_paths(train_metadata_og, train_image_dir, train_folder_name)
test_metadata = get_image_paths(test_metadata_og, test_image_dir, test_folder_name)
# valid_metadata = get_image_paths(valid_metadata, train_image_dir, train_folder_name)

interval = 9
train_metadata = get_data_in_intervals(train_metadata, interval)
# valid_metadata = get_data_in_intervals(valid_metadata, interval)
test_metadata = get_data_in_intervals(test_metadata, interval)

train_metadata = create_bins(train_metadata)
test_metadata = create_bins(test_metadata)
# valid_metadata = create_bins(valid_metadata)

from sklearn.model_selection import train_test_split

X,y = train_metadata[["storm_id","image_list","ocean"]], train_metadata["Wind Labels"]
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2, random_state=101, stratify=train_metadata["storm_id"], shuffle=True)
X_train, X_valid = pd.DataFrame(X_train), pd.DataFrame(X_valid)
train_metadata = pd.concat([X_train, y_train], axis = 1).reset_index().drop("index", axis=1)
valid_metadata = pd.concat([X_valid, y_valid], axis = 1).reset_index().drop("index", axis=1)

train_metadata, train_label_dict = label_encode(train_metadata, 'Wind Labels')
test_metadata, test_label_dict = label_encode(test_metadata,'Wind Labels')
valid_metadata, valid_label_dict = label_encode(valid_metadata,'Wind Labels')
# Out:
# Bins created!
# Bins created!

# %%
transform = transforms.Compose([
        # transforms.RandomResizedCrop(224),
        transforms.Resize((224, 224)),
        # transforms.RandomRotation(90),
        # transforms.Grayscale(num_output_channels=1),
        # transforms.RandomHorizontalFlip(),
        # transforms.RandomVerticalFlip(),
        # transforms.CenterCrop(90),
        transforms.ToTensor(),
        # transforms.Normalize([0.5], [0.5])
        # transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))
])

# %%
trainset = HurricaneImageDataset(train_metadata, transform)
testset = HurricaneImageDataset(test_metadata, transform)
validset = HurricaneImageDataset(valid_metadata, transform)

trainloader = DataLoader(trainset, batch_size=256, shuffle=True)
testloader = DataLoader(testset, batch_size=256, shuffle=True)
validloader = DataLoader(validset, batch_size=256, shuffle=True)

# %%
sample_size = 30
batch_size = 128
num_rows = 5

display_sample_images(trainloader, batch_size, sample_size, num_rows, train_label_dict)

# %%
train_label_dict
# Out:
# {0: '15 to 25', 1: '26 to 35', 2: '36 to 45', 3: '46 to 75', 4: '>=76'}

# %%
# Densenet161
densenet161 = models.densenet161(pretrained = True)
# densenet161
# Freeze Parameters so we dont backprop through them:
for param in densenet161.parameters():
    param.requires_grad = False
# # Create Custom Classifier:
classifier = nn.Sequential(nn.Linear(2208, 512),
                           nn.ReLU(),
                           nn.Dropout(0.20),
                          #  nn.Linear(512, 128),
                          #  nn.ReLU(),
                          #  nn.Dropout(0.20),
                           nn.Linear(512, 5))
# Assign Classifier
densenet161.classifier = classifier
densenet161.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=2208, out_features=512, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.2, inplace=False)
#   (3): Linear(in_features=512, out_features=5, bias=True)
# )

# %%
model = densenet161 # resize images to 366x366, batch_size = 64
model_name = "densenet161_ADAM_e35_b256_00003_classifier"
model_path = "/content/drive/MyDrive/DS5500 Data/{}.pt".format(model_name)
model = loadModel(model_path, densenet161)
model.to(device)
# print(model)

# Loss function
criterion = nn.CrossEntropyLoss()
print("Loss Function:\n", criterion)
# Optimizer
print("")
lr = 0.0003
optimizer = optim.Adam(model.parameters(), lr=lr)
factor = 0.3
scheduler = ReduceLROnPlateau(optimizer, factor=0.3, patience=3, min_lr=lr*(factor**6), eps=1e-8, verbose=True)
# scheduler = None
# optimizer = optim.SGD(model.parameters(), lr=0.0001)
print("Optimizer:\n", optimizer)

epochs = 17
model_name = "densenet161_ADAM_e35_b256_00003_classifier_v2"
losses_filename = "{}_losses".format(model_name)
print("")
model_losses = train(model, trainloader, validloader, epochs, criterion, optimizer, scheduler, device, model_name, losses_filename)
# Out:
# Loss Function:
#  CrossEntropyLoss()
#
# Optimizer:
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0003
#     weight_decay: 0
# )
#
# Saving model losses to drive.
# Epoch: 1/17, Train Loss: 0.50401, Validation Loss: 0.65947
# Decrease in Validation Loss: (inf to 0.659474). Saving Model...
# Saving model losses to drive.
# Epoch: 2/17, Train Loss: 0.48532, Validation Loss: 0.65784
# Decrease in Validation Loss: (0.659474 to 0.657843). Saving Model...
# Saving model losses to drive.
# Epoch: 3/17, Train Loss: 0.46245, Validation Loss: 0.64641
# Decrease in Validation Loss: (0.657843 to 0.646412). Saving Model...
# Saving model losses to drive.
# Epoch: 4/17, Train Loss: 0.44854, Validation Loss: 0.64695
# Saving model losses to drive.
# Epoch: 5/17, Train Loss: 0.43236, Validation Loss: 0.64473
# Decrease in Validation Loss: (0.646412 to 0.644727). Saving Model...
# Saving model losses to drive.
# Epoch: 6/17, Train Loss: 0.41623, Validation Loss: 0.62697
# Decrease in Validation Loss: (0.644727 to 0.626971). Saving Model...
# Saving model losses to drive.
# Epoch: 7/17, Train Loss: 0.39875, Validation Loss: 0.66865
# Saving model losses to drive.
# Epoch: 8/17, Train Loss: 0.37952, Validation Loss: 0.62121
# Decrease in Validation Loss: (0.626971 to 0.621213). Saving Model...
# Saving model losses to drive.
# Epoch: 9/17, Train Loss: 0.36450, Validation Loss: 0.61853
# Decrease in Validation Loss: (0.621213 to 0.618531). Saving Model...
# Saving model losses to drive.
# Epoch: 10/17, Train Loss: 0.34944, Validation Loss: 0.61948
# Saving model losses to drive.
# Epoch: 11/17, Train Loss: 0.33131, Validation Loss: 0.62609
# Saving model losses to drive.
# Epoch: 12/17, Train Loss: 0.32234, Validation Loss: 0.63623
# Saving model losses to drive.
# Epoch: 13/17, Train Loss: 0.30808, Validation Loss: 0.60434
# Decrease in Validation Loss: (0.618531 to 0.604339). Saving Model...
# Saving model losses to drive.
# Epoch: 14/17, Train Loss: 0.29333, Validation Loss: 0.61920
# Saving model losses to drive.
# Epoch: 15/17, Train Loss: 0.28108, Validation Loss: 0.62887
# Saving model losses to drive.
# Epoch: 16/17, Train Loss: 0.26579, Validation Loss: 0.59443
# Decrease in Validation Loss: (0.604339 to 0.594431). Saving Model...
# Saving model losses to drive.
# Epoch: 17/17, Train Loss: 0.26145, Validation Loss: 0.61382
#
# Time Taken for Training: 03:04:09.54
#
# Saving model losses to drive.

# %% [markdown]
# Loss Function:
#  CrossEntropyLoss()
#
# Optimizer:
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0003
#     weight_decay: 0
# )
#
# Saving model losses to drive.
# Epoch: 1/35, Train Loss: 0.86735, Validation Loss: 0.85258
# Decrease in Validation Loss: (inf to 0.852584). Saving Model...
# Saving model losses to drive.
# Epoch: 2/35, Train Loss: 0.83753, Validation Loss: 0.83565
# Decrease in Validation Loss: (0.852584 to 0.835653). Saving Model...
# Saving model losses to drive.
# Epoch: 3/35, Train Loss: 0.81425, Validation Loss: 0.85378
# Saving model losses to drive.
# Epoch: 4/35, Train Loss: 0.79144, Validation Loss: 0.79790
# Decrease in Validation Loss: (0.835653 to 0.797895). Saving Model...
# Saving model losses to drive.
# Epoch: 5/35, Train Loss: 0.77609, Validation Loss: 0.79699
# Decrease in Validation Loss: (0.797895 to 0.796991). Saving Model...
# Saving model losses to drive.
# Epoch: 6/35, Train Loss: 0.75544, Validation Loss: 0.78790
# Decrease in Validation Loss: (0.796991 to 0.787902). Saving Model...
# Saving model losses to drive.
# Epoch: 7/35, Train Loss: 0.73462, Validation Loss: 0.77008
# Decrease in Validation Loss: (0.787902 to 0.770079). Saving Model...
# Saving model losses to drive.
# Epoch: 8/35, Train Loss: 0.71647, Validation Loss: 0.75977
# Decrease in Validation Loss: (0.770079 to 0.759767). Saving Model...
# Saving model losses to drive.
# Epoch: 9/35, Train Loss: 0.70638, Validation Loss: 0.74822
# Decrease in Validation Loss: (0.759767 to 0.748216). Saving Model...
# Saving model losses to drive.
# Epoch: 10/35, Train Loss: 0.68125, Validation Loss: 0.74409
# Decrease in Validation Loss: (0.748216 to 0.744086). Saving Model...
# Saving model losses to drive.
# Epoch: 11/35, Train Loss: 0.66465, Validation Loss: 0.72815
# Decrease in Validation Loss: (0.744086 to 0.728153). Saving Model...
# Saving model losses to drive.
# Epoch: 12/35, Train Loss: 0.64632, Validation Loss: 0.72196
# Decrease in Validation Loss: (0.728153 to 0.721963). Saving Model...
# Saving model losses to drive.
# Epoch: 13/35, Train Loss: 0.62617, Validation Loss: 0.72132
# Decrease in Validation Loss: (0.721963 to 0.721315). Saving Model...
# Saving model losses to drive.
# Epoch: 14/35, Train Loss: 0.60497, Validation Loss: 0.72126
# Decrease in Validation Loss: (0.721315 to 0.721258). Saving Model...
# Saving model losses to drive.
# Epoch: 15/35, Train Loss: 0.58634, Validation Loss: 0.70640
# Decrease in Validation Loss: (0.721258 to 0.706398). Saving Model...
# Saving model losses to drive.
# Epoch: 16/35, Train Loss: 0.56513, Validation Loss: 0.68874
# Decrease in Validation Loss: (0.706398 to 0.688738). Saving Model...
# Saving model losses to drive.
# Epoch: 17/35, Train Loss: 0.54370, Validation Loss: 0.67459
# Decrease in Validation Loss: (0.688738 to 0.674588). Saving Model...
# Saving model losses to drive.
# Epoch: 18/35, Train Loss: 0.52261, Validation Loss: 0.66323
# Decrease in Validation Loss: (0.674588 to 0.663225). Saving Model...
# Saving model losses to drive.
# Epoch: 19/35, Train Loss: 0.51791, Validation Loss: 0.67607

# %%
criterion = nn.CrossEntropyLoss()
model_name = "densenet161_ADAM_e35_b256_0001_classifier"
model = densenet161
model_path = "/content/drive/MyDrive/DS5500 Data/{}.pt".format(model_name)
model = loadModel(model_path, densenet161)
model.to(device)
test(model,testloader,criterion,5, test_label_dict)

# %%
criterion = nn.CrossEntropyLoss()
model_name = "densenet161_ADAM_e35_b256_00003_classifier"
model = densenet161
model_path = "/content/drive/MyDrive/DS5500 Data/{}.pt".format(model_name)
model = loadModel(model_path, densenet161)
model.to(device)
test(model,testloader,criterion,5, test_label_dict)
# Out:
# Test Loss: 1.0448853312827098
# Test Accuracy of 15 to 25: 67.172%. Frac: 5498.0/8185.0
# Test Accuracy of 26 to 35: 53.035%. Frac: 4552.0/8583.0
# Test Accuracy of 36 to 45: 26.943%. Frac: 1716.0/6369.0
# Test Accuracy of 46 to 75: 66.827%. Frac: 6652.0/9954.0
# Test Accuracy of >=76: 76.628%. Frac: 3695.0/4822.0
#
#  Test Accuracy (Overall): 58.326. Frac 22113.0/37913.0

# %%
# Densenet161
densenet161 = models.densenet161(pretrained = True)
# densenet161
# Freeze Parameters so we dont backprop through them:
for param in densenet161.parameters():
    param.requires_grad = False
# # Create Custom Classifier:
classifier = nn.Sequential(nn.Linear(2208, 512),
                           nn.ReLU(),
                           nn.Dropout(0.20),
                           nn.Linear(512, 128),
                           nn.ReLU(),
                           nn.Dropout(0.20),
                           nn.Linear(128, 5))
# Assign Classifier
densenet161.classifier = classifier
densenet161.classifier
# Out:
# Sequential(
#   (0): Linear(in_features=2208, out_features=512, bias=True)
#   (1): ReLU()
#   (2): Dropout(p=0.2, inplace=False)
#   (3): Linear(in_features=512, out_features=128, bias=True)
#   (4): ReLU()
#   (5): Dropout(p=0.2, inplace=False)
#   (6): Linear(in_features=128, out_features=5, bias=True)
# )

# %%
model = densenet161 # resize images to 366x366, batch_size = 64
# model_name = "densenet161_ADAM_e35_b256_00003_classifier"
# model_path = "/content/drive/MyDrive/DS5500 Data/{}.pt".format(model_name)
# model = loadModel(model_path, densenet161)
model.to(device)
# print(model)

# Loss function
criterion = nn.CrossEntropyLoss()
print("Loss Function:\n", criterion)
# Optimizer
print("")
lr = 0.0003
optimizer = optim.Adam(model.parameters(), lr=lr)
factor = 0.3
scheduler = ReduceLROnPlateau(optimizer, factor=0.3, patience=2, min_lr=lr*(factor**6), eps=1e-8, verbose=True)
# scheduler = None
# optimizer = optim.SGD(model.parameters(), lr=0.0001)
print("Optimizer:\n", optimizer)

epochs = 35
model_name = "densenet161_ADAM_e35_b256_00003_classifier_v2"
losses_filename = "{}_losses".format(model_name)
print("")
model_losses = train(model, trainloader, validloader, epochs, criterion, optimizer, scheduler, device, model_name, losses_filename)
# Out:
# Loss Function:
#  CrossEntropyLoss()
#
# Optimizer:
#  Adam (
# Parameter Group 0
#     amsgrad: False
#     betas: (0.9, 0.999)
#     eps: 1e-08
#     lr: 0.0003
#     weight_decay: 0
# )
